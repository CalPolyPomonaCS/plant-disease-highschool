# %% [markdown]
# # Plant Disease Classification: Comparing ML Algorithms
#
# **Title:** Comparing Classical Machine Learning and Deep Learning Models for Plant Leaf Disease Classification on the PlantVillage Dataset.
#
# **Research question:** How do classical ML algorithms (SVM, Random Forest, XGBoost, ...) compare with deep learning models (CNN, transfer learning) for classifying plant leaf diseases from images, in terms of accuracy, training time, and model size?
#
# ---
# ### How to use this notebook
# This notebook is a **template**. Every code cell below is a set of instructions and `# TODO:` comments. **You write the code.** Work top to bottom, one TODO at a time. Ask your instructor if you get stuck.
#
# **Before you start:** Runtime -> Change runtime type -> **T4 GPU**.

# %% [markdown]
# # Step 1 - Setup + Download
# *(Weeks 1-2)*
#
# In this step you set up your tools, download the dataset, and look at the images so you understand what you are working with.

# %% [markdown]
# ## Week 1 - Environment & first look
#
# **Goals:** mount Google Drive, install libraries, download the PlantVillage dataset, and display your first leaf image.

# %%
# Mount Google Drive so your files are saved between sessions.
# TODO

# %%
# Install / import the libraries you will need throughout the project.
# TODO

# %%
# Check that the GPU is turned on.
# TODO
# If the list is empty, go to Runtime -> Change runtime type -> T4 GPU.

# %%
# Download the PlantVillage dataset (use the `raw/color` images).
# TODO
#       (or download a zip). This is large, so only do it once and keep it in Drive.
# TODO

# %%
# "Hello image": load and show ONE leaf image to confirm everything works.
# TODO

# %% [markdown]
# ## Week 2 - Understand the data
#
# **Goals:** build a table of every image with its label, see how many images each class has, and view one sample leaf per class.

# %%
# Build a dataframe describing every image: file path, class label, crop, disease.
# The folder name is the class (e.g. "Tomato___Early_blight"). Crop and disease are the
# two halves of that name split on "___".
# TODO

# %%
# How balanced is the dataset? Count images per class.
# TODO

# %%
# Look at the leaves: show one example image from each of the 38 classes.
# TODO

# %% [markdown]
# # Step 2 - Data Preprocessing
# *(Weeks 3-4)*
#
# Here you build a smaller, balanced sample, split it into train/val/test, and prepare two kinds of inputs: a feature table for classical ML and an image pipeline for deep learning.

# %% [markdown]
# ## Week 3 - Balanced sample & splits
#
# **Goals:** take ~150 images per class (so every class is equally represented), split into train/validation/test, and save the list so every later step uses the exact same images.

# %%
# Take a balanced sample of 150 images per class.
# A balanced sample means each class has the same number of images, so no class dominates.
# TODO

# %%
# Split into train / validation / test (e.g. 70% / 15% / 15%), stratified by class.
# "Stratified" keeps the class balance the same in each split.
# TODO
#       again to split the rest into train/val), passing stratify=labels
# TODO

# %%
# Save the sample list to Drive so you can reload the exact same images later.
# TODO

# %%
# Quick EDA on the sample to confirm it looks right.
# TODO

# %% [markdown]
# ## Week 4 - Feature extraction + image pipeline
#
# You will prepare data **two ways**:
# 1. **Classical features** - turn each image into a row of numbers (color, texture, shape) for sklearn/XGBoost.
# 2. **Deep pipeline** - feed raw images (resized) straight into the neural networks, with augmentation.

# %%
# CLASSICAL FEATURES: write a function that turns one image into a feature vector.
# Ideas for features:
#   - Color histograms: counts of pixel colors in RGB and/or HSV
#   - Texture: GLCM (skimage.feature.graycomatrix/graycoprops) and LBP (local_binary_pattern)
#   - Simple stats: mean/std of each color channel
# TODO
#       computes the features above, and returns one flat numpy array

# %%
# Build the feature matrix X and labels y for each split, then save them.
# TODO

# %%
# DEEP PIPELINE: build an image loader for the neural networks.
# TODO
#       at that size and normalize pixels to 0-1
# TODO

# %%
# Look at one batch of augmented training images to make sure it works.
# TODO

# %% [markdown]
# # Step 3 - Training & Evaluation
# *(Weeks 5-8)*
#
# Now you train many models and compare them. Keep ONE shared results table and add a row for every model so the final comparison is easy.

# %%
# Create one shared results table you will append to all through Step 3.
# TODO
#       computes accuracy and macro-F1 (sklearn.metrics) and appends a dict to results

# %% [markdown]
# ## Week 5 - Classical models, round 1
#
# Train four simple classifiers on the feature matrix from Week 4: Logistic Regression, K-Nearest Neighbors, Decision Tree, and Naive Bayes.

# %%
# Load the features you saved in Week 4.
# TODO

# %%
# Logistic Regression.
# TODO

# %%
# K-Nearest Neighbors.
# TODO

# %%
# Decision Tree.
# TODO

# %%
# Naive Bayes.
# TODO

# %%
# Show a confusion matrix for your best model so far.
# TODO

# %% [markdown]
# ## Week 6 - Classical models, round 2 + tuning
#
# Train stronger models (SVM, Random Forest, XGBoost) and try **hyperparameter variations** to improve them.

# %%
# Support Vector Machine (SVM).
# TODO

# %%
# Random Forest.
# TODO

# %%
# XGBoost.
# TODO

# %%
# Compare your classical models so far.
# TODO

# %% [markdown]
# ## Week 7 - CNN from scratch
#
# Build your own small Convolutional Neural Network (CNN) and train it on the raw images.

# %%
# Build a small CNN.
# A CNN stacks Conv2D + MaxPooling layers (to learn image patterns), then Flatten + Dense
# layers, ending in a Dense layer with 38 units and softmax (one score per class).
# TODO

# %%
# Train the CNN on the image pipeline.
# TODO

# %%
# Plot training curves.
# TODO

# %%
# Save the model and record its result.
# TODO

# %% [markdown]
# ## Week 8 - Transfer learning + final comparison
#
# Use models that were already trained on millions of images (transfer learning), then compare EVERYTHING.

# %%
# Transfer learning: reuse a pretrained network as a feature extractor.
# Pattern: load the base model with include_top=False and weights='imagenet', freeze it
# (base.trainable=False), then add your own GlobalAveragePooling + Dense(38, softmax) head.
# TODO

# %%
# TODO

# %%
# TODO

# %%
# FINAL COMPARISON of every model you trained.
# TODO

# %%
# Error analysis on your single best model.
# TODO

# %%
# Final score: evaluate the best model on the TEST set (do this only once, at the end).
# The test set was never used for training or tuning, so it gives an honest final number.
# TODO

# %% [markdown]
# # Step 4 - Write Report
# *(Weeks 9-10)*
#
# Turn your results into a clear story, and build a small demo.

# %% [markdown]
# ## Week 9 & 10 - Draft & demo
#
# **Goals:** draft the report and build a "predict a new leaf" demo.

# %% [markdown]
# ### Report draft (write in these markdown cells)
#
# - **Introduction:** Why does automatic plant disease detection matter?
# - **Dataset:** What is PlantVillage? How many classes/images? What sample did you use?
# - **Methods:** What features and what models did you try?
# - **Results:** Your comparison table and charts. Which model won?
# - **Discussion:** Why might one model beat another? What surprised you?
#
# *TODO: write your draft here as you go.*

# %%
# Prediction demo: upload a leaf photo and let your best model guess the disease.
# TODO
